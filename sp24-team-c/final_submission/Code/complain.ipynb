# %%
import pandas as pd

# load the data
data = pd.read_csv('clustered_results_with_representatives.csv')

# count types unique values
print(data['cluster_representative'].value_counts())
# Out:
# cluster_representative
# Parking Enforcement Transportation - Traffic Division Enforcement & Abandoned Vehicles Parking Enforcement             5418
# Mattress Pickup Public Works Department Sanitation Mattress_Pickup                                                     2628
# Requests for Street Cleaning Public Works Department Street Cleaning Requests for Street Cleaning                      2016
# Improper Storage of Trash (Barrels) Public Works Department Code Enforcement Improper Storage of Trash (Barrels)       1952
# Missed Bulk Item Pickup: District 02 Public Works Department Sanitation Missed Trash/Recycling/Yard Waste/Bulk Item    1409
# Schedule a Bulk Item Pickup Public Works Department Sanitation Schedule a Bulk Item Pickup                             1313
# Request for Pothole Repair Public Works Department Highway Maintenance Request for Pothole Repair                      1200
# Unshoveled Sidewalk Public Works Department Code Enforcement Unshoveled Sidewalk                                       1139
# Request for Recycling Cart Public Works Department Recycling Request for Recycling Cart                                1022
# CE Collection Public Works Department Street Cleaning CE Collection                                                     959
# Poor Conditions of Property Public Works Department Code Enforcement Poor Conditions of Property                        873
# Street Light Outages // Contractor Light Public Works Department Street Lights Street Light Outages                     824
# Abandoned Vehicles Transportation - Traffic Division Enforcement & Abandoned Vehicles Abandoned Vehicles                671
# Schedule Bulk Item Pickup Public Works Department Sanitation Schedule a Bulk Item Pickup SS                             644
# Needle Pickup Mayor's 24 Hour Hotline Needle Program Needle Pickup                                                      551
# Tree Maintenance Parks & Recreation Department Trees Tree Maintenance Requests                                          547
# Pick up Dead Animal Public Works Department Street Cleaning Pick up Dead Animal                                         491
# Sign Repair Transportation - Traffic Division Signs & Signals Sign Repair                                               437
# Rodent Activity Inspectional Services Environmental Services Rodent Activity                                            377
# Sidewalk Repair (Make Safe) Public Works Department Highway Maintenance Sidewalk Repair (Make Safe)                     375
# SCH1/6Unsatisfactory Living Conditions Inspectional Services Housing Unsatisfactory Living Conditions                   370
# Animal Generic Request Animal Control Animal Issues Animal Generic Request                                              309
# New Tree Requests Parks & Recreation Department Trees New Tree Requests                                                 307
# Ground Maintenance: Brophy Park - BPRD Parks & Recreation Department Park Maintenance & Safety Ground Maintenance       304
# Illegal Dumping Public Works Department Code Enforcement Illegal Dumping                                                283
# Contractor Complaints Public Works Department Highway Maintenance Contractor Complaints                                 240
# Heat - Excessive  Insufficient Inspectional Services Housing Heat - Excessive  Insufficient                             239
# Building Inspection Request Inspectional Services Building Building Inspection Request                                  234
# Pest Infestation - Residential Inspectional Services Housing Pest Infestation - Residential                             209
# Empty Litter Basket Public Works Department Highway Maintenance Empty Litter Basket                                     197
# Catchbasin Boston Water & Sewer Commission Catchbasin Catchbasin                                                        193
# Request for Snow Plowing Public Works Department Street Cleaning Request for Snow Plowing                               170
# SCH1/05Maintenance Complaint - Residential Inspectional Services Housing Maintenance Complaint - Residential            153
# Public Works General Request Public Works Department Administrative & General Requests Public Works General Request     152
# Unsanitary Conditions - Food Inspectional Services Health Unsanitary Conditions - Food                                  129
# Fire Mayor's 24 Hour Hotline Notification Notification                                                                  121
# Graffiti Removal Property Management Graffiti Graffiti Removal                                                          106
# Work w/out Permit Inspectional Services Building Work w/out Permit                                                      104
# Working Beyond Hours Inspectional Services Building Working Beyond Hours                                                 78
# Loud Parties/Music/People Boston Police Department Noise Disturbance Loud Parties/Music/People                           50
# Name: count, dtype: int64

# %%
import pandas as pd

# load the data
csv_path = 'clustered_results_with_categories.csv'
df = pd.read_csv(csv_path)

# define the specified updates
specified_updates = {
    "SCH1/05Maintenance Complaint - Residential Inspectional Services Housing Maintenance Complaint - Residential": "Housing and Building Management",
    "SCH1/6Unsatisfactory Living Conditions Inspectional Services Housing Unsatisfactory Living Conditions": "Housing and Building Management",
    "Heat - Excessive  Insufficient Inspectional Services Housing Heat - Excessive  Insufficient": "Housing and Building Management",
}

# update the 'Category' column based on the specified updates
df.loc[df['cluster_representative'].isin(specified_updates.keys()), 'Category'] = df['cluster_representative'].map(specified_updates)

# save the updated data to a new CSV file
updated_csv_path_v2 = 'clustered_results_with_categories_2.csv'
df.to_csv(updated_csv_path_v2, index=False)

print(f"Updated CSV has been saved to: {updated_csv_path_v2}")
# Out:
# Updated CSV has been saved to: clustered_results_with_categories_2.csv

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# load the data
data_path = 'clustered_results_with_categories.csv'  
df = pd.read_csv(data_path)


boston_map = folium.Map(location=[42.3601, -71.0589], zoom_start=12)
geojson_path = 'BPDA_Neighborhood_Boundaries.geojson'  # Change this to the path of your GeoJSON file
folium.GeoJson(geojson_path, name='Boston Neighborhoods').add_to(boston_map)

# define categories
categories = df['Category'].unique()

# 
for category in categories:

    category_data = df[df['Category'] == category][['latitude', 'longitude']]
    heat_data = [[row['latitude'], row['longitude']] for index, row in category_data.iterrows()]
    
    HeatMap(heat_data).add_to(folium.FeatureGroup(name=category).add_to(boston_map))

folium.LayerControl().add_to(boston_map)
boston_map.save('boston_issues_heatmaps.html')
print("Heatmaps have been saved to 'boston_issues_heatmaps.html'")
# Out:
# Heatmaps have been saved to 'boston_issues_heatmaps.html'

# %%
import folium
import pandas as pd

# load the data
data_path = 'clustered_results_with_categories.csv'  
df = pd.read_csv(data_path)

# create a map centered on Boston
boston_map = folium.Map(location=[42.3601, -71.0589], zoom_start=12)
geojson_path = 'BPDA_Neighborhood_Boundaries.geojson'  # Change this to the path of your GeoJSON file
folium.GeoJson(geojson_path, name='Boston Neighborhoods').add_to(boston_map)

# define the color map
color_map = {
    "Traffic and Vehicle Management": "red",
    "Urban Cleaning and Environmental Maintenance": "blue",
    "Infrastructure and Public Facilities Maintenance": "green",
    "Housing and Building Management": "purple",
    "Public Safety and Health": "orange",
    "Municipal Services and Requests": "darkblue",
    "Water and Drainage Management": "cyan",
}

# create a feature group for each category
feature_groups = {category: folium.FeatureGroup(name=category, show=False) for category in color_map.keys()}

# add circle markers to the feature groups
for index, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        color=color_map[row['Category']],
        fill=True,
        fill_color=color_map[row['Category']],
        fill_opacity=0.6,
        popup=row['Category'],
    ).add_to(feature_groups[row['Category']])

for feature_group in feature_groups.values():
    feature_group.add_to(boston_map)

folium.LayerControl().add_to(boston_map)

boston_map.save('boston_issues_circle_markers.html')

print("Circle markers with all categories correctly displayed have been saved to 'boston_issues_circle_markers.html'")
# Out:
# Circle markers with all categories correctly displayed have been saved to 'boston_issues_circle_markers.html'

# %%
import matplotlib.pyplot as plt
import pandas as pd

# plot the number of issues by category
csv_path = 'clustered_results_with_categories.csv'  
df = pd.read_csv(csv_path)
category_counts = df['Category'].value_counts()
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Issues by Category')
plt.xlabel('Category')
plt.ylabel('Number of Issues')
plt.xticks(rotation=45, ha="right", fontweight='bold', fontsize=13)
plt.tight_layout()
plt.show()
