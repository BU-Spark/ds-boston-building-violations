# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
import pandas as pd
from difflib import SequenceMatcher

df = pd.read_csv("./code_enforcement_violations.csv")
df.dropna(subset=['contact_addr1','contact_addr2'], how="any", inplace=True)
#print(df.isnull().sum())
df['contact_addr'] = df['contact_addr1'] + ', ' + df['contact_addr2']
df.drop(['contact_addr1', 'contact_addr2'], axis=1, inplace=True)
grouped_data = df.groupby(['latitude', 'longitude']).agg(lambda x: x.tolist()).reset_index()
grouped_data = df.groupby(['latitude', 'longitude'])[['contact_addr']].agg(lambda x: x.tolist()).reset_index()
df
# Out:
#          case_no ticket_no             status_dttm  status code  value  \
# 1       CE737958  LEHCWL02  2024-02-03 16:40:00+00    Open    1     25
# 7       CE737952  VPEJHZ12  2024-02-03 15:35:00+00    Open    1     25
# 10      CE737950  XWCJYP08  2024-02-03 15:28:00+00    Open    1     25
# 13      CE737948  M4FUZ008  2024-02-03 15:11:00+00    Open    1     25
# 14      CE737947  XTPVAU02  2024-02-03 15:08:00+00    Open    1     25
# ...          ...       ...                     ...     ...  ...    ...
# 683256  CE217199    EKYY06  2000-01-01 20:57:00+00  Closed    1     25
# 683257  CE217198    E18606  2000-01-01 20:20:00+00  Closed    1     25
# 683260  CE217195    CKAU06  2000-01-01 18:44:00+00  Closed    1     25
# 683261  CE217194    CDE806  2000-01-01 18:33:00+00  Closed    1     25
# 683262  CE218090       006  2000-01-01 00:35:00+00  Closed    1     25
#
#                         description violation_stno violation_sthigh  \
# ...

# %%
def most_frequent_string(lst):
    max_count = 0
    most_frequent_str = None
    for item in lst:
        count = lst.count(item)
        if count > max_count:
            max_count = count
            most_frequent_str = item
    return most_frequent_str
grouped_data['contact_addr'] = grouped_data['contact_addr'].apply(most_frequent_string)
grouped_data
#addr = grouped_data["contact_addr"]
#temp = np.array([])
#for x in addr:
    #x = x[:]
    #temp = np.append(temp, x)
#print(temp)
# Out:
#
#
#
#
#
#
#
#
#
#
#
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# E
#
#
#
# O
#
#
#
#
#
#
#
#
#
#
#
#
# O
#
# O
#
#
#
#
#
#
#
#
# ...

# %%
grouped_data["contact_addr"] = temp
grouped_data
# Out:
#         latitude  longitude                                       contact_addr
# 0      42.230437 -71.133033  2310 WASHINGTON ST, CHARLES RIVER REALTY INVES...
# 1      42.231447 -71.134472  2310 WASHINGTON ST, CHARLES RIVER REALTY INVES...
# 2      42.232680 -71.129851                 14 BARRY DRIVE, C/O RICHARD GAGLIO
# 3      42.233040 -71.129681                 23 LESEUR RD, C/O ROBERTA I CANNER
# 4      42.233420 -71.129481              3 AVIATION RD, C/O CHRISTINE HOEPFNER
# ...          ...        ...                                                ...
# 32068  42.392754 -71.006743  75 FEDERAL ST, Unit 4TH FLOOR, C/O TRINITY FIN...
# 32069  42.392947 -71.009912  75 FEDERAL ST, Unit 4TH FLOOR, C/O TRINITY FIN...
# 32070  42.393008 -71.007530  75 FEDERAL ST, Unit 4TH FLOOR, C/O TRINITY FIN...
# 32071  42.393215 -71.009242  75 FEDERAL ST, Unit 4TH FLOOR, C/O TRINITY FIN...
# 32072  42.394429 -71.000290  ONE CONGRESS ST 10TH FLR, C/O HYM INVESTMENT G...
#
# ...

# %%
merged_df = pd.merge(df, grouped_data, on=['latitude', 'longitude'], suffixes=('_df', '_grouped_data'), how='left')
merged_df.drop(['contact_addr_df'], axis=1, inplace=True)
merged_df
# Out:
#          case_no ticket_no             status_dttm  status code  value  \
# 0       CE737958  LEHCWL02  2024-02-03 16:40:00+00    Open    1     25
# 1       CE737952  VPEJHZ12  2024-02-03 15:35:00+00    Open    1     25
# 2       CE737950  XWCJYP08  2024-02-03 15:28:00+00    Open    1     25
# 3       CE737948  M4FUZ008  2024-02-03 15:11:00+00    Open    1     25
# 4       CE737947  XTPVAU02  2024-02-03 15:08:00+00    Open    1     25
# ...          ...       ...                     ...     ...  ...    ...
# 256852  CE217199    EKYY06  2000-01-01 20:57:00+00  Closed    1     25
# 256853  CE217198    E18606  2000-01-01 20:20:00+00  Closed    1     25
# 256854  CE217195    CKAU06  2000-01-01 18:44:00+00  Closed    1     25
# 256855  CE217194    CDE806  2000-01-01 18:33:00+00  Closed    1     25
# 256856  CE218090       006  2000-01-01 00:35:00+00  Closed    1     25
#
#                         description violation_stno violation_sthigh  \
# ...

# %%
print(merged_df.isnull().sum())
# Out:
# case_no                           0
# ticket_no                        19
# status_dttm                       0
# status                            0
# code                              0
# value                             0
# description                       0
# violation_stno                    0
# violation_sthigh             185427
# violation_street                  0
# violation_suffix               1889
# violation_city                   12
# violation_state                   0
# violation_zip                    40
# ward                              0
# contact_city                      3
# contact_state                    77
# contact_zip                      44
# sam_id                            0
# latitude                          0
# longitude                         0
# location                          0
# contact_addr_grouped_data         0
# dtype: int64
